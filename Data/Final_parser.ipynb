# %% [markdown]
# ## Mainfin.ru

# %% [markdown]
# Для скачивания данных с сайта нам потребуется список всех городов, воспользуемся википедией

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://ru.wikipedia.org/wiki/Список_городов_России"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table = soup.find('table', {'class': 'standard sortable'})

headers = [header.text.strip() for header in table.find_all('th')]

rows = []
for row in table.find_all('tr')[1:]: 
    cells = row.find_all('td')
    rows.append([cell.text.strip() for cell in cells])

df = pd.DataFrame(rows, columns=headers)

df
# Out:
#          № Герб      Город                Регион Федеральный округ Население  \
# 0        1           Абаза               Хакасия         Сибирский    12 272
# 1        2          Абакан               Хакасия         Сибирский   184 769
# 2        3        Абдулино  Оренбургская область       Приволжский    17 274
# 3        4          Абинск    Краснодарский край             Южный    39 511
# 4        5         Агидель          Башкортостан       Приволжский    14 219
# ...    ...  ...        ...                   ...               ...       ...
# 1120  1121       Ярославль   Ярославская область       Центральный   577 279
# 1121  1122          Ярцево    Смоленская область       Центральный    41 452
# 1122  1123       Ясногорск      Тульская область       Центральный    15 269
# 1123  1124           Ясный  Оренбургская область       Приволжский    15 471
# 1124  1125          Яхрома    Московская область       Центральный    14 011
#
#      Основание илипервое упоминание Статус города[4]  \
# 0                              1867             1966
# 1                              1734             1931
# 2                              1795             1923
# 3                              1863             1963
# 4                              1980             1991
# ...                             ...              ...
# 1120                           1010             1071
# 1121                           1610             1926
# 1122                           1578             1958
# 1123                           1961             1979
# 1124                           1841             1940
#
#                                Прежние названия
# 0         Абаканский Завод, Абаканско-Заводское
# 1                     Усть-Абаканское (до 1931)
# 2
# 3         Абинское (до 1863);Абинская (до 1962)
# 4
# ...                                         ...
# 1120
# 1121
# 1122                          Лаптево (до 1965)
# 1123
# 1124  Суровцево, посёлок Покровской мануфактуры
#
# [1125 rows x 9 columns]

# %%
df['Население'] = df['Население'].str.replace(r'\D', '', regex=True).astype(int)

# %% [markdown]
# Нужно перевести названия в английскую транслитерацию

# %%
from transliterate import translit
import pandas as pd


def transliterate_city(city_name):
    try:
        return translit(city_name, 'ru', reversed=True).replace("'", "")
    except Exception as e:
        print(f"Ошибка транслитерации для {city_name}: {e}")

df['City (Transliteration)'] = df['Город'].apply(transliterate_city)

print(df[['Город', 'City (Transliteration)']])
# Out:
#           Город City (Transliteration)
# 0         Абаза                  Abaza
# 1        Абакан                 Abakan
# 2      Абдулино               Abdulino
# 3        Абинск                 Abinsk
# 4       Агидель                 Agidel
# ...         ...                    ...
# 1120  Ярославль              Jaroslavl
# 1121     Ярцево               Jartsevo
# 1122  Ясногорск             Jasnogorsk
# 1123      Ясный                 Jasnyj
# 1124     Яхрома                Jahroma
#
# [1125 rows x 2 columns]

# %% [markdown]
# Формируем ссылки для запросов

# %%
def generate_link(city_translit):
    return f'https://mainfin.ru/banki/poisk/bankomaty/{city_translit.lower()}'

df['Link'] = df['City (Transliteration)'].apply(generate_link)

print(df[['Город', 'City (Transliteration)', 'Link']])
# Out:
#           Город City (Transliteration)  \
# 0         Абаза                  Abaza
# 1        Абакан                 Abakan
# 2      Абдулино               Abdulino
# 3        Абинск                 Abinsk
# 4       Агидель                 Agidel
# ...         ...                    ...
# 1120  Ярославль              Jaroslavl
# 1121     Ярцево               Jartsevo
# 1122  Ясногорск             Jasnogorsk
# 1123      Ясный                 Jasnyj
# 1124     Яхрома                Jahroma
#
#                                                    Link
# 0        https://mainfin.ru/banki/poisk/bankomaty/abaza
# 1       https://mainfin.ru/banki/poisk/bankomaty/abakan
# 2     https://mainfin.ru/banki/poisk/bankomaty/abdulino
# 3       https://mainfin.ru/banki/poisk/bankomaty/abinsk
# 4       https://mainfin.ru/banki/poisk/bankomaty/agidel
# ...                                                 ...
# 1120  https://mainfin.ru/banki/poisk/bankomaty/jaros...
# 1121  https://mainfin.ru/banki/poisk/bankomaty/jartsevo
# 1122  https://mainfin.ru/banki/poisk/bankomaty/jasno...
# 1123    https://mainfin.ru/banki/poisk/bankomaty/jasnyj
# 1124   https://mainfin.ru/banki/poisk/bankomaty/jahroma
#
# [1125 rows x 3 columns]

# %%
top_100_cities = df.nlargest(100, 'Население')

# %%
import requests
from bs4 import BeautifulSoup
from tqdm import tqdm
import re
from time import sleep
import random
import pandas as pd
import logging

logging.basicConfig(level=logging.INFO, format="%(asctime)s - %(levelname)s - %(message)s")

adr = []
bank_name = []
schedule = []
city_list = []
population_list = []

MAX_RETRIES = 3

for _, row in tqdm(top_100_cities.iterrows(), desc="Обрабатываем города", unit="город", total=len(top_100_cities)):
    city = row['Город']
    population = row['Население']
    url = row['Link']
    retries = 0

    if url not in ["https://mainfin.ru/banki/poisk/bankomaty/abakan"]:
        logging.info(f"Пропускаем город: {url}")
        continue

    while retries < MAX_RETRIES:
        try:
            response = requests.get(url)
            if response.status_code != 200:
                raise Exception(f"Ошибка загрузки страницы: {response.status_code}")

            soupB = BeautifulSoup(response.text, 'html.parser')

            try:
                s_count = soupB.findAll('label', {'class': "mapobject-count"})[0].get_text()
                s_count = int(''.join(re.findall(r'\d', s_count)))
            except IndexError:
                logging.warning(f"Не удалось найти количество банкоматов для {url}")
                retries += 1
                continue

            n_pages = s_count // 20 + 1  # +1 на случай если остаток есть

            for p in tqdm(range(1, n_pages + 1), desc=f"Обрабатываем страницы для {city}", unit="страница"):
                page_url = f"{url}?page={p}"
                page = requests.get(page_url)
                if page.status_code != 200:
                    raise Exception(f"Ошибка загрузки страницы: {page.status_code}")

                soup = BeautifulSoup(page.text, 'html.parser')

                banks = [_.get_text() for _ in soup.find_all('a', {'class': 'bank small'})]
                addresses = [_.get_text().replace('\xa0', '') for _ in soup.find_all('a', {'class': 'address pm'})]
                schedules = [_.get_text().strip() for _ in soup.find_all('td', {'class': 'col-sm-3'})]

                bank_name.extend(banks)
                adr.extend(addresses)
                schedule.extend(schedules)
                city_list.extend([city] * len(banks))
                population_list.extend([population] * len(banks))
                sleep(random.uniform(1, 3))

            sleep(random.uniform(1, 3))
            break

        except Exception as e:
            retries += 1
            logging.error(f"Ошибка при обработке города {url}: {e}. Попытка {retries} из {MAX_RETRIES}")
            if retries >= MAX_RETRIES:
                logging.error(f"Не удалось обработать город {url} после {MAX_RETRIES} попыток. Пропускаем город.")
                break
# Out:
# Обрабатываем города:   0%|                           | 0/100 [00:00<?, ?город/s]2025-02-19 00:33:29,525 - INFO - Пропускаем город: https://mainfin.ru/banki/poisk/bankomaty
# Обрабатываем страницы для Абакан:  67%|██ | 10/15 [00:27<00:13,  2.63s/страница]
# Обрабатываем страницы для Абакан:  73%|██▏| 11/15 [00:30<00:11,  2.88s/страница]
# Обрабатываем страницы для Абакан:  80%|██▍| 12/15 [00:33<00:08,  2.80s/страница]
# Обрабатываем страницы для Абакан:  87%|██▌| 13/15 [00:36<00:05,  2.92s/страница]
# Обрабатываем страницы для Абакан:  93%|██▊| 14/15 [00:38<00:02,  2.75s/страница]
# Обрабатываем страницы для Абакан: 100%|███| 15/15 [00:42<00:00,  2.84s/страница]
# Обрабатываем города:  99%|█████████████████▊| 99/100 [00:46<00:00,  2.15город/s]2025-02-19 00:34:15,570 - INFO - Пропускаем город: https://mainfin.ru/banki/poisk/bankomaty/balakovo
# Обрабатываем города: 100%|█████████████████| 100/100 [00:46<00:00,  2.17город/s]

# %%
# Чек
print("Длины списков до синхронизации:")
print(f"City: {len(city_list)}")
print(f"Population: {len(population_list)}")
print(f"Bank Name: {len(bank_name)}")
print(f"Address: {len(adr)}")
print(f"Schedule: {len(schedule)}")

max_length = max(len(city_list), len(population_list), len(bank_name), len(adr), len(schedule))

city_list.extend([None] * (max_length - len(city_list)))
population_list.extend([None] * (max_length - len(population_list)))
bank_name.extend([None] * (max_length - len(bank_name)))
adr.extend([None] * (max_length - len(adr)))
schedule.extend([None] * (max_length - len(schedule)))

df_results = pd.DataFrame({
    'City': city_list,
    'Population': population_list,
    'Bank Name': bank_name,
    'Address': adr,
    'Schedule': schedule
})

df_results = df_results[df_results[['City', 'Population', 'Bank Name', 'Address']].notna().any(axis=1)]

df_results.reset_index(drop=True, inplace=True)
# Out:
# Длины списков до синхронизации:
# City: 290
# Population: 290
# Bank Name: 290
# Address: 290
# Schedule: 580

# %%
df_results
# Out:
#        City  Population                     Bank Name  \
# 0    Абакан    184769.0   Азиатско-Тихоокеанский Банк
# 1    Абакан    184769.0   Азиатско-Тихоокеанский Банк
# 2    Абакан    184769.0   Азиатско-Тихоокеанский Банк
# 3    Абакан    184769.0                    Альфа-Банк
# 4    Абакан    184769.0                    Альфа-Банк
# ..      ...         ...                           ...
# 285  Абакан    184769.0  Хакасский муниципальный банк
# 286  Абакан    184769.0  Хакасский муниципальный банк
# 287  Абакан    184769.0  Хакасский муниципальный банк
# 288  Абакан    184769.0  Хакасский муниципальный банк
# 289  Абакан    184769.0                     Хоум Банк
#
#                                          Address  \
# 0         г. Абакан, просп. Дружбы Народов, д.59
# 1               г. Абакан, ул.Карла Маркса, д.63
# 2                 г. Абакан, ул.Вокзальная, д.17
# 3            г. Абакан, пр-кт Дружбы Народов, 50
# 4                    г. Абакан, ул. Пушкина, 100
# ..                                           ...
# 285       г. Абакан, просп. Дружбы Народов, д.50
# 286                г. Абакан, ул.Некрасова, д.31
# 287  г. Абакан, Нижняя Согра, ул.Буденного, д.78
# 288                г. Абакан, ул.Хакасская, д.73
# 289              г. Абакан, просп. Ленина, д.70а
#
#                                   Schedule
# 0      БанкоматАзиатско-Тихоокеанский Банк
# 1                            Круглосуточно
# 2      БанкоматАзиатско-Тихоокеанский Банк
# 3                            Круглосуточно
# 4      БанкоматАзиатско-Тихоокеанский Банк
# ..                                     ...
# 285                          Круглосуточно
# 286  БанкоматыХакасский муниципальный банк
# 287                          Круглосуточно
# 288  БанкоматыХакасский муниципальный банк
# 289                          Круглосуточно
#
# [290 rows x 5 columns]

# %% [markdown]
# Можем спарсить любой город, планирую обучить модели на городах из датасета, а в сервисе подключить все города

# %% [markdown]
# Для работы дальше необходимо преобразовать адреса в координаты

# %% [markdown]
# ## Геокод Протона

# %%
import pandas as pd
import requests

def get_coordinates_photon(address):
    try:
        url = "https://photon.komoot.io/api/"
        params = {
            "q": address,
            "limit": 1
        }
        
        response = requests.get(url, params=params)
        
        if response.status_code == 200:
            data = response.json()
            if data['features']:
                lat = data['features'][0]['geometry']['coordinates'][1]
                lon = data['features'][0]['geometry']['coordinates'][0]
                return lat, lon
            else:
                return None
        else:
            print(f"Ошибка {response.status_code}: {response.text}")
            return None
    except Exception as e:
        print(f"Ошибка при обработке адреса '{address}': {e}")
        return None

random_sample = df_results

random_sample['coordinates'] = random_sample['Address'].apply(get_coordinates_photon)
random_sample[['latitude', 'longitude']] = pd.DataFrame(random_sample['coordinates'].tolist(), index=random_sample.index)

random_sample.drop(columns=['coordinates'], inplace=True)

random_sample

# %% [markdown]
# ## Геокод Янедкса

# %% [markdown]
# Можно пользоваться Яндексом, но дорого

# %%
import pandas as pd
import requests

YANDEX_API_KEY = "e2dcd6db-799a-4fbf-941d-6d95dee958b0"

def get_coordinates_yandex(address, api_key=YANDEX_API_KEY):
    url = "https://geocode-maps.yandex.ru/1.x/"
    params = {
        "geocode": address,
        "format": "json",
        "apikey": api_key
    }
    response = requests.get(url, params=params)
    if response.status_code == 200:
        data = response.json()
        try:
            pos = data["response"]["GeoObjectCollection"]["featureMember"][0]["GeoObject"]["Point"]["pos"]
            lon, lat = map(float, pos.split())
            return lat, lon
        except (IndexError, KeyError):
            return None
    else:
        print(f"Ошибка {response.status_code}: {response.text}")
        return None

df_results['coordinates'] = df_results['Address'].apply(get_coordinates_yandex)
df_results[['latitude', 'longitude']] = pd.DataFrame(df_results['coordinates'].tolist(), index=df_results.index)

df_results.drop(columns=['coordinates'], inplace=True)
print(df_results)

# %% [markdown]
# ## Геокод Гугла

# %% [markdown]
# Аналогично

# %%
import pandas as pd
import googlemaps

GOOGLE_API_KEY = "AIzaSyA_I8tor5ykxGOKxFHYc-jyW2DDpwyAjxg"

gmaps = googlemaps.Client(key=GOOGLE_API_KEY)

def get_coordinates_google(address):
    try:
        geocode_result = gmaps.geocode(address)
        if geocode_result:
            location = geocode_result[0]["geometry"]["location"]
            return location["lat"], location["lng"]
        else:
            return None
    except Exception as e:
        print(f"Ошибка при обработке адреса '{address}': {e}")
        return None


random_sample = df_results.sample(n=10, random_state=42) if len(df_results) > 10 else df_results

random_sample['coordinates'] = random_sample['Address'].apply(get_coordinates_google)
random_sample[['latitude', 'longitude']] = pd.DataFrame(random_sample['coordinates'].tolist(), index=random_sample.index)

random_sample.drop(columns=['coordinates'], inplace=True)

print(random_sample[['Bank Name', 'Address', 'latitude', 'longitude']])

# %% [markdown]
# ## Геокод DaData

# %% [markdown]
# Не бесплатно

# %%
import pandas as pd
from dadata import Dadata

DADATA_API_KEY = "9b4bb56467c8ba414a3cd54edc5ca752cec961f9"
DADATA_SECRET_KEY = "67cbcd2f3744ac47b43f79dabbbc2f1f266af131"

dadata = Dadata(DADATA_API_KEY, DADATA_SECRET_KEY)

def get_coordinates_dadata(address):
    try:
        result = dadata.clean("Address", address)
        if result and "geo_lat" in result and "geo_lon" in result:
            lat = float(result["geo_lat"])
            lon = float(result["geo_lon"])
            return lat, lon
        else:
            return None
    except Exception as e:
        print(f"Ошибка при обработке адреса '{address}': {e}")
        return None

df_results['coordinates'] = df_results['Address'].apply(get_coordinates_dadata)
df_results['coordinates'] = df_results['coordinates'].apply(
    lambda x: (None, None) if x is None else x
)

df_results[['latitude', 'longitude']] = pd.DataFrame(
    df_results['coordinates'].tolist(), index=random_sample.index
)
df_results.drop(columns=['coordinates'], inplace=True)

df_results
# Out:
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Карла Маркса, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вокзальная, д.17': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, пр-кт Дружбы Народов, 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пушкина, 100': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кирова, д.103': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тараса Шевченко, д.62': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.33': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18, стр. 3': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вокзальная, д.17': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кошурникова, д.23': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.5в': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.78': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.20': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вяткина, д.21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чехова, д.122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вяткина, д.33а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кирова, д.99 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Гагарина, д.7': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'Республика Хакасия, г.Абакан, ул.Кирова, д.120, корп. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.86а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.29': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.63а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, д.113': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.117': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.193': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.5': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Володарского, д.4': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Хакасская, д.6': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.151а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Белоярская, д.110': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Белоярская, д.68': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Павших Коммунаров, д.129': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кати Перекрещенко, д.3а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, д.92, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Стофато, д.12': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.86': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.72': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Дружбы Народов, д. 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, 92к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина 62': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Герцена 21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, кв-л Молодежный, д. 15': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 26': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Торговая, д. 5 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Некрасова, д. 22 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Чехова, 122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пирятинская, 18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Итыгина, 19а, стр.': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, 67': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пирятинская, 13': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, 32': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Советская, 207': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д. 90': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Катерная, д. 54а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Хлебная, д. 16 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Крылова, 84': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, 41а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тараса Шевченко, 62': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Крылова, 72': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д. 23': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Торговая, 5': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.52': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Маршала Жукова, д. 18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пушкина, д. 99': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пушкина, д. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Павших Коммунаров, 129': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д. 59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 45': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 190': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Чертыгашева, 77': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Щетинкина, 20': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Советская, 169': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Некрасова, 31': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Чертыгашева, 102': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 2а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, 151а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Стофато, 12': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул. Пушкина, 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 165': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.70а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.123': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.77': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.7': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.88': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгешева, д.112': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Итыгина, д.2': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.39': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кати Перекрещенко, д.3а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.283, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгешева, д.57а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.160': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.66 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Павших Коммунаров, д.129': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.32': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торосова, д.7 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Катанова, д.10': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.22': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чехова, д.122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.127': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, д.113': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.76': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.5': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.151': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.10': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.122': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.80': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Шевченко, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Володарского, д.4': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.22 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.39': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Лермонтова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Герцена, д.21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торосова, д.21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, д.92к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Хакасская, д.73': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.99': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.86': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.70а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Карла Маркса, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вокзальная, д.17': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.100': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Ленина, д.62': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кирова, д.103': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.33': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кошурникова, д.23': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.78, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вокзальная, д.17': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18, стр. 3': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.20': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.78': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.5в': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вяткина, д.21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.74': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.23': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чехова, д.122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Вяткина, д.33а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Гагарина, д.7': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.86а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.29': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.63а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торосова, д.7 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.151': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.14а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Володарского, д.4': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.117': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, д.113': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Хакасская, д.6': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Стофато, д.5д': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, д.92, корп. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Павших Коммунаров, д.129': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.72': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, 11к, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, 100': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Итыгина, 2': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Белоярская, 68': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тараса Шевченко, 63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 44': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 127': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 113': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Флотская, 13': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, 38а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Стофато, 12а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, 29': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Герцена, 21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тараса Шевченко, 62': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, 5': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 45': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Павших Коммунаров, 129': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, 90': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, 23': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Хлебная, 16 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Катерная, 54а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 207': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чехова, 122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, 22 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, 18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, 5а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, кв-л Молодежный, 15': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, 67': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, 92к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, 26': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Итыгина, 19а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, 31': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 165а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Дружбы Народов, 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, 50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, 2а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, 151а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, 20': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, 102': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Стофато, 12': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.3а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.58': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.77': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.7': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.66 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.3': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.43': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Стофато, д.12': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Итыгина, д.2': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.27': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Ленина, д.59': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Флотская, д.13': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пирятинская, д.22': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.160': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.39': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.84': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.151': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.57а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.57а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чертыгашева, д.112': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Аскизская, д.283, стр. 1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торосова, д.7 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Павших Коммунаров, д.127а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.30': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Шевченко, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.22 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Лермонтова, д.18': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Герцена, д.21': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Тельмана, д.92к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.1': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.122': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.39': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Крылова, д.66 Б': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.22': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Чехова, д.122а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Пушкина, д.127': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Советская, д.113': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.5а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.10': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.80': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Володарского, д.4': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Торговая, д.32': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Катанова, д.10': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Кравченко, д.11к': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Маршала Жукова, д.86': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Щетинкина, д.63': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Дружбы Народов, д.50': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Некрасова, д.31': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, Нижняя Согра, ул.Буденного, д.78': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, ул.Хакасская, д.73': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# Ошибка при обработке адреса 'г. Абакан, просп. Ленина, д.70а': 403 Client Error: Forbidden for url: https://cleaner.dadata.ru/api/v1/clean/Address
# For more information check: https://httpstatuses.com/403
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 28
#      22 df_results['coordinates'] = df_results['Address'].apply(get_coordinates_dadata)
#      23 df_results['coordinates'] = df_results['coordinates'].apply(
#      24     lambda x: (None, None) if x is None else x
#      25 )
#      27 df_results[['latitude', 'longitude']] = pd.DataFrame(
# ---> 28     df_results['coordinates'].tolist(), index=random_sample.index
#      29 )
#      30 df_results.drop(columns=['coordinates'], inplace=True)
#      32 df_results
#
# NameError: name 'random_sample' is not defined
